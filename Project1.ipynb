# %% [markdown]
# # Importing relevant libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Loading the Life Expectancy Data

# %%
df = pd.read_csv('Life_Expectancy_Data.csv')
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df.size
# Out:
# 64636

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Descriptive statistics

# %%
df.describe(include='all')
# Out:
#             Country         Year      Status  Life expectancy   \
# count          2938  2938.000000        2938       2928.000000
# unique          193          NaN           2               NaN
# top     Afghanistan          NaN  Developing               NaN
# freq             16          NaN        2426               NaN
# mean            NaN  2007.518720         NaN         69.224932
# std             NaN     4.613841         NaN          9.523867
# min             NaN  2000.000000         NaN         36.300000
# 25%             NaN  2004.000000         NaN         63.100000
# 50%             NaN  2008.000000         NaN         72.100000
# 75%             NaN  2012.000000         NaN         75.700000
# max             NaN  2015.000000         NaN         89.000000
#
#         Adult Mortality  infant deaths      Alcohol  percentage expenditure  \
# count       2928.000000    2938.000000  2744.000000             2938.000000
# ...

# %% [markdown]
# ## Dealing with missing values

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df_new = df.dropna(axis=0) #drops the missing values

# %%
df_new
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df_new.size   #large part of the data has been erased. Not advisable
# Out:
# 36278

# %%
df_new.describe(include='all')
# Out:
#             Country         Year      Status  Life expectancy   \
# count          1649  1649.000000        1649       1649.000000
# unique          133          NaN           2               NaN
# top     Afghanistan          NaN  Developing               NaN
# freq             16          NaN        1407               NaN
# mean            NaN  2007.840509         NaN         69.302304
# std             NaN     4.087711         NaN          8.796834
# min             NaN  2000.000000         NaN         44.000000
# 25%             NaN  2005.000000         NaN         64.400000
# 50%             NaN  2008.000000         NaN         71.700000
# 75%             NaN  2011.000000         NaN         75.000000
# max             NaN  2015.000000         NaN         89.000000
#
#         Adult Mortality  infant deaths      Alcohol  percentage expenditure  \
# count       1649.000000    1649.000000  1649.000000             1649.000000
# ...

# %% [markdown]
# ## Exploring the PDFs

# %%
df_new
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
for col in df_new.columns:
    print(col)
# Out:
# Country
# Year
# Status
# Life expectancy
# Adult Mortality
# infant deaths
# Alcohol
# percentage expenditure
# Hepatitis B
# Measles
#  BMI
# under-five deaths
# Polio
# Total expenditure
# Diphtheria
#  HIV/AIDS
# GDP
# Population
#  thinness  1-19 years
#  thinness 5-9 years
# Income composition of resources
# Schooling

# %%
df_new.columns[6]
# Out:
# 'Alcohol'

# %%
sns.distplot(df_new['Life expectancy ']) # a little bit distributed, though not perfectly
# Out:
# /home/ayodeji/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Life expectancy ', ylabel='Density'>

# %%
sns.distplot(df_new['Adult Mortality'])
# Out:
# /home/ayodeji/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Adult Mortality', ylabel='Density'>

# %%
sns.distplot(df_new['infant deaths'])
# Out:
# /home/ayodeji/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='infant deaths', ylabel='Density'>

# %%
df_new.describe(include='all')
# Out:
#             Country         Year      Status  Life expectancy   \
# count          1649  1649.000000        1649       1649.000000
# unique          133          NaN           2               NaN
# top     Afghanistan          NaN  Developing               NaN
# freq             16          NaN        1407               NaN
# mean            NaN  2007.840509         NaN         69.302304
# std             NaN     4.087711         NaN          8.796834
# min             NaN  2000.000000         NaN         44.000000
# 25%             NaN  2005.000000         NaN         64.400000
# 50%             NaN  2008.000000         NaN         71.700000
# 75%             NaN  2011.000000         NaN         75.000000
# max             NaN  2015.000000         NaN         89.000000
#
#         Adult Mortality  infant deaths      Alcohol  percentage expenditure  \
# count       1649.000000    1649.000000  1649.000000             1649.000000
# ...

# %%
q = df_new['infant deaths'].quantile(0.99)
data_cleaned = df_new[df_new['infant deaths']<q]
sns.distplot(data['infant deaths'])
# Out:
# /home/ayodeji/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='infant deaths', ylabel='Density'>

# %%
data_cleaned.describe(include='all')
# Out:
#             Country         Year      Status  Life expectancy   \
# count          1632  1632.000000        1632       1632.000000
# unique          132          NaN           2               NaN
# top     Afghanistan          NaN  Developing               NaN
# freq             16          NaN        1390               NaN
# mean            NaN  2007.833946         NaN         69.385355
# std             NaN     4.098272         NaN          8.777943
# min             NaN  2000.000000         NaN         44.000000
# 25%             NaN  2005.000000         NaN         64.475000
# 50%             NaN  2008.000000         NaN         71.800000
# 75%             NaN  2011.000000         NaN         75.000000
# max             NaN  2015.000000         NaN         89.000000
#
#         Adult Mortality  infant deaths      Alcohol  percentage expenditure  \
# count       1632.000000    1632.000000  1632.000000             1632.000000
# ...

# %% [markdown]
# ## Checking the OLS assumption

# %%
# selecting the dependent and independent variable
# depenedent variable: Life expectancy, Adult Mortality, Infant deaths, GDP
# independent variable: Status (life exp), Alcohol (Life exp), Alcohol, HIV/AIDS, Diphtheria (Adult Mortality), 
#independent variable: Hepatits B, Measles, Polio, thiness 1-19, thiness 5-9, Diphtheria, HIV/AIDS (Infant deaths)
# independent variable: Population, Total expenditure (GDP),

# %%
f, (ax2, ax3) = plt.subplots(1, 2, sharey=True, figsize =(15, 3)) #sharey -> share 'Price' as y

ax2.scatter(data_cleaned['Status'],data_cleaned['Life expectancy '])
ax2.set_title('Status and Life expectancy')
ax3.scatter(data_cleaned['Alcohol'],data_cleaned['Life expectancy '])
ax3.set_title('Alcohol and Life expectancy')



plt.show()

# %%
f, (ax4, ax5, ax6) = plt.subplots(1, 3, sharey=True, figsize =(15, 3)) #sharey -> share 'Price' as y
ax4.scatter(data_cleaned['Alcohol'],data_cleaned['Adult Mortality'])
ax4.set_title('Alcohol and Adult Mortality')
ax5.scatter(data_cleaned[' HIV/AIDS'],data_cleaned['Adult Mortality'])
ax5.set_title('HIV/AIDS and Adult Mortality')
ax6.scatter(data_cleaned['Diphtheria '],data_cleaned['Adult Mortality'])
ax6.set_title('Diphtheria and Adult Mortality')
# Out:
# Text(0.5, 1.0, 'Diphtheria and Adult Mortality')

# %%
f, (ax7, ax8, ax9) = plt.subplots(1, 3, sharey=True, figsize =(15, 3))
ax7.scatter(data_cleaned['Hepatitis B'],data_cleaned['infant deaths'])
ax7.set_title('Hepatitis B and Infant death')
ax8.scatter(data_cleaned['Measles '],data_cleaned['infant deaths'])
ax8.set_title('Measles and Infant death')
ax9.scatter(data_cleaned['Polio'],data_cleaned['infant deaths'])
ax9.set_title('Polio and Infant death')
# Out:
# Text(0.5, 1.0, 'Polio and Infant death')

# %%
f, (ax10, ax11, ax12, ax13) = plt.subplots(1, 4, sharey=True, figsize =(15, 3))

ax10.scatter(data_cleaned[' thinness  1-19 years'],data_cleaned['infant deaths'])
ax10.set_title('thinness 1-19 years and Infant death')
ax11.scatter(data_cleaned[' thinness 5-9 years'],data_cleaned['infant deaths'])
ax11.set_title('thinness 5-9 years and Infant death')
ax12.scatter(data_cleaned['Diphtheria '],data_cleaned['infant deaths'])
ax12.set_title('Diphtheria and Infant death')
ax13.scatter(data_cleaned[' HIV/AIDS'],data_cleaned['infant deaths'])
ax13.set_title('HIV/AIDS and Infant death')
# Out:
# Text(0.5, 1.0, 'HIV/AIDS and Infant death')

# %%
f, (ax14, ax15) = plt.subplots(1, 2, sharey=True, figsize =(15, 3))

ax14.scatter(data_cleaned['Population'],data_cleaned['GDP'])
ax14.set_title('Population and GDP')
ax15.scatter(data_cleaned['Total expenditure'],data_cleaned['GDP'])
ax15.set_title('Total expenditure and GDP')
# Out:
# Text(0.5, 1.0, 'Total expenditure and GDP')

# %%
log_life_expectancy = np.log(data_cleaned['Life expectancy '])
data_cleaned['log_Life expectancy'] = log_life_expectancy
data_cleaned
# Out:
# <ipython-input-104-235d73ba8156>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['log_Life expectancy'] = log_life_expectancy
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# ...

# %% [markdown]
# # Linear regression

# %% [markdown]
# ## Declare inputs and the targets

# %%
df_new.columns[9]
# Out:
# 'Measles '

# %%
# The target(s) (dependent variable) is 'life expectancy'
targets = data_cleaned['Life expectancy ']

# The inputs are everything BUT the dependent variable, so we can simply drop it
inputs = data_cleaned[['Alcohol']]

# %% [markdown]
# ## Scale the data

# %%
# Import the scaling module
from sklearn.preprocessing import StandardScaler

# Create a scaler object
scaler = StandardScaler()
# Fit the inputs (calculate the mean and standard deviation feature-wise)
scaler.fit(inputs)
# Out:
# StandardScaler()

# %%
# Scale the features and store them in a new variable (the actual scaling procedure)
inputs_scaled = scaler.transform(inputs)

# %% [markdown]
# ## Train-Test Split

# %%
# Import the module for the split
from sklearn.model_selection import train_test_split

# Split the variables with an 80-20 split and some random state
# To have the same split as mine, use random_state = 365
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=365)

# %% [markdown]
# ## Create the regression

# %%
from sklearn.linear_model import LinearRegression
# Create a linear regression object
reg = LinearRegression()
# Fit the regression with the scaled TRAIN inputs and targets
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Let's check the outputs of the regression
# I'll store them in y_hat as this is the 'theoretical' name of the predictions
y_hat = reg.predict(x_train)

# %%
# The simplest way to compare the targets (y_train) and the predictions (y_hat) is to plot them on a scatter plot
# The closer the points to the 45-degree line, the better the prediction
plt.scatter(y_train, y_hat)
# Let's also name the axes
plt.xlabel('Targets (y_train)',size=18)
plt.ylabel('Predictions (y_hat)',size=18)
# Sometimes the plot will have different scales of the x-axis and the y-axis
# This is an issue as we won't be able to interpret the '45-degree line'
# We want the x-axis and the y-axis to be the same

plt.show()

# %%
# Another useful check of our model is a residual plot
# We can plot the PDF of the residuals and check for anomalies
sns.distplot(y_train - y_hat)

# Include a title
plt.title("Residuals PDF", size=18)

# In the best case scenario this plot should be normally distributed
# In our case we notice that there are many negative residuals (far away from the mean)
# Given the definition of the residuals (y_train - y_hat), negative values imply
# that y_hat (predictions) are much higher than y_train (the targets)
# This is food for thought to improve our model
# Out:
# /home/ayodeji/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Residuals PDF')

# %%
# Find the R-squared of the model
reg.score(x_train,y_train)

# Note that this is NOT the adjusted R-squared
# in other words... find the Adjusted R-squared to have the appropriate measure :)
# Out:
# 0.1710753231451606

# %% [markdown]
# ### life expectancy and alcohol are weakly correlated

# %%
# The target(s) (dependent variable) is 'life expectancy'
targets = data_cleaned['Adult Mortality']

# The inputs are everything BUT the dependent variable, so we can simply drop it
inputs = data_cleaned[['Alcohol', ' HIV/AIDS', 'Diphtheria ']]

# %%
scaler = StandardScaler()
# Fit the inputs (calculate the mean and standard deviation feature-wise)
scaler.fit(inputs)
# Out:
# StandardScaler()

# %%
# Scale the features and store them in a new variable (the actual scaling procedure)
inputs_scaled = scaler.transform(inputs)

# %%
# Split the variables with an 80-20 split and some random state
# To have the same split as mine, use random_state = 365
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=365)

# %%
# Fit the regression with the scaled TRAIN inputs and targets
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Let's check the outputs of the regression
# I'll store them in y_hat as this is the 'theoretical' name of the predictions
y_hat = reg.predict(x_train)

# %%
# The simplest way to compare the targets (y_train) and the predictions (y_hat) is to plot them on a scatter plot
# The closer the points to the 45-degree line, the better the prediction
plt.scatter(y_train, y_hat)
# Let's also name the axes
plt.xlabel('Targets (y_train)',size=18)
plt.ylabel('Predictions (y_hat)',size=18)
# Sometimes the plot will have different scales of the x-axis and the y-axis
# This is an issue as we won't be able to interpret the '45-degree line'
# We want the x-axis and the y-axis to be the same

plt.show()

# %%
reg.score(x_train,y_train)   ## Poorly correlated
# Out:
# 0.34276594494591806

# %%
df_new.columns[17]
# Out:
# 'Population'

# %%
# The target(s) (dependent variable) is 'life expectancy'
targets = data_cleaned['infant deaths']

# The inputs are everything BUT the dependent variable, so we can simply drop it
inputs = data_cleaned[['Measles ', ' HIV/AIDS', 'Diphtheria ', 'Polio', 'Hepatitis B', ' thinness  1-19 years', ' thinness 5-9 years']]

scaler = StandardScaler()
# Fit the inputs (calculate the mean and standard deviation feature-wise)
scaler.fit(inputs)

# Scale the features and store them in a new variable (the actual scaling procedure)
inputs_scaled = scaler.transform(inputs)

# Split the variables with an 80-20 split and some random state
# To have the same split as mine, use random_state = 365
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=365)

# Fit the regression with the scaled TRAIN inputs and targets
reg.fit(x_train,y_train)

 #Let's check the outputs of the regression
# I'll store them in y_hat as this is the 'theoretical' name of the predictions
y_hat = reg.predict(x_train)

# The simplest way to compare the targets (y_train) and the predictions (y_hat) is to plot them on a scatter plot
# The closer the points to the 45-degree line, the better the prediction
plt.scatter(y_train, y_hat)
# Let's also name the axes
plt.xlabel('Targets (y_train)',size=18)
plt.ylabel('Predictions (y_hat)',size=18)
# Sometimes the plot will have different scales of the x-axis and the y-axis
# This is an issue as we won't be able to interpret the '45-degree line'
# We want the x-axis and the y-axis to be the same

plt.show()

# %%
reg.score(x_train,y_train)
# Out:
# 0.34605143898474877

# %%
# The target(s) (dependent variable) is 'life expectancy'
targets = data_cleaned['under-five deaths ']

# The inputs are everything BUT the dependent variable, so we can simply drop it
inputs = data_cleaned[['Measles ', ' HIV/AIDS', 'Diphtheria ', 'Polio', 'Hepatitis B', ' thinness  1-19 years', ' thinness 5-9 years']]

scaler = StandardScaler()
# Fit the inputs (calculate the mean and standard deviation feature-wise)
scaler.fit(inputs)

# Scale the features and store them in a new variable (the actual scaling procedure)
inputs_scaled = scaler.transform(inputs)

# Split the variables with an 80-20 split and some random state
# To have the same split as mine, use random_state = 365
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=365)

# Fit the regression with the scaled TRAIN inputs and targets
reg.fit(x_train,y_train)

 #Let's check the outputs of the regression
# I'll store them in y_hat as this is the 'theoretical' name of the predictions
y_hat = reg.predict(x_train)

# The simplest way to compare the targets (y_train) and the predictions (y_hat) is to plot them on a scatter plot
# The closer the points to the 45-degree line, the better the prediction
plt.scatter(y_train, y_hat)
# Let's also name the axes
plt.xlabel('Targets (y_train)',size=18)
plt.ylabel('Predictions (y_hat)',size=18)
# Sometimes the plot will have different scales of the x-axis and the y-axis
# This is an issue as we won't be able to interpret the '45-degree line'
# We want the x-axis and the y-axis to be the same

plt.show()

# %%
reg.score(x_train,y_train)
# Out:
# 0.32253926305862646

# %%
# The target(s) (dependent variable) is 'life expectancy'
targets = data_cleaned['Population']

# The inputs are everything BUT the dependent variable, so we can simply drop it
inputs = data_cleaned[['Adult Mortality', 'infant deaths']]

scaler = StandardScaler()
# Fit the inputs (calculate the mean and standard deviation feature-wise)
scaler.fit(inputs)

# Scale the features and store them in a new variable (the actual scaling procedure)
inputs_scaled = scaler.transform(inputs)

# Split the variables with an 80-20 split and some random state
# To have the same split as mine, use random_state = 365
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=365)

# Fit the regression with the scaled TRAIN inputs and targets
reg.fit(x_train,y_train)

 #Let's check the outputs of the regression
# I'll store them in y_hat as this is the 'theoretical' name of the predictions
y_hat = reg.predict(x_train)

# The simplest way to compare the targets (y_train) and the predictions (y_hat) is to plot them on a scatter plot
# The closer the points to the 45-degree line, the better the prediction
plt.scatter(y_train, y_hat)
# Let's also name the axes
plt.xlabel('Targets (y_train)',size=18)
plt.ylabel('Predictions (y_hat)',size=18)
# Sometimes the plot will have different scales of the x-axis and the y-axis
# This is an issue as we won't be able to interpret the '45-degree line'
# We want the x-axis and the y-axis to be the same

plt.show()

# %%
reg.score(x_train,y_train)
# Out:
# 0.09618796384934125
